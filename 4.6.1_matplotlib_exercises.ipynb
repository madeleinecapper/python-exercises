# %% [markdown]
# # 4.6.1 Matplotlib Exercises

# %% [markdown]
# ### Use matplotlib to plot y = x^2 - x + 2

# %%
import matplotlib.pyplot as plt
x = range(-40, 42)
y = [n ** 2 - n + 2 for n in x]
plt.annotate('(0,0)', fontsize = 15, xy = (0,0), xytext=(0,200), arrowprops = {'facecolor': 'plum'})
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Create and label 4 separate plots for the following equations (choose a range for x that makes sense):
# #### y=√x
# #### y=x^3
# #### y=tan(x)
# #### y=2^x

# %%
x = range(0,20)
y = [n ** 0.5 for n in x]
plt.plot(x, y)
plt.show()

# %%
x = range(-10,10)
y = [n ** 3 for n in x]
plt.plot(x,y)
plt.show()

# %%
from math import tan
x = range(-7, 7)
y = [tan(n) for n in x]
plt.figure(figsize = (14,6))
plt.plot(x,y)
plt.title('Horrible approximation of tangent')
plt.show()

# %%
x = range(-10,10)
y = [2 ** n for n in x]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Combine the figures you created in the last step into one large figure with 4 subplots

# %%
from math import tan
x1 = range(0,8)
x2 = range(-7,7)
x3 = range(0, 7)
x4 = range(-10,10)
y1 = [n ** 0.5 for n in x1]
y2 = [n ** 3 for n in x2]
y3 = [tan(n) for n in x3]
y4 = [2 ** n for n in x4]

plt.figure(figsize = (25,18))

plt.subplot(221)
plt.plot(x1,y1)
plt.title('sqrt(x)', fontsize = 15)
plt.subplot(222)
plt.plot(x2,y2)
plt.title('x^3', fontsize = 15)
plt.subplot(223)
plt.plot(x3,y3)
plt.title('tan(x)', fontsize = 15)
plt.subplot(224)
plt.plot(x4,y4)
plt.title('2^x', fontsize = 15)
plt.suptitle('some plots', fontsize = 30)

plt.show()

# %%
from math import tan
x1 = range(0,10)
x2 = range(-10,10)
y1 = [n ** 0.5 for n in x1]
y2 = [n ** 3 for n in x2]
y3 = [tan(n) for n in x1]
y4 = [2 ** n for n in x2]
plt.figure(figsize = (13, 8))
plt.plot(x1,y1, c= 'magenta', label = 'sqrt(x)')
plt.plot(x2,y2, c = 'green', label = 'x^3')
plt.plot(x3,y3, c = 'turquoise', label = 'tan(x)')
plt.plot(x4,y4, c = 'blue', label = '2^x')
plt.legend(loc = 'upper left', fontsize = 15)
plt.title('Overlap!', fontsize = 20)
plt.show()

# %%
x1, y1 = [0,0],[0,40]
x2, y2 = [0,1],[40,0]
x3, y3 = [1,2],[0,40]
x4, y4 = [2,2],[40,0]
x5, y5 = [3, 4], [0, 40]
x6, y6 = [4,5],[40,0]
x7, y7 = [3,5],[0,0]
x8,y8 = [6,6],[0,40]
x9,y9 = [6,8],[40,40]
x10,y10 = [8,8],[40,20]
x11,y11 = [8,6], [20,20]
x12,y12 = [7,8], [20,0]
x13,y13 = [9,9], [0,40]
x14, y14 = [9,11], [40,40]
x15,y15 = [9,11], [20,20]
plt.plot(x1,y1,x2,y2,x3,y3,x4,y4,x5,y5,x6,y6,x7,y7,x8,y8,x9,y9,x10,y10,x11,y11,x12,y12,x13,y13,x14,y14,x15,y15)
plt.show()
